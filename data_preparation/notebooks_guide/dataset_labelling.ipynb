# %%
import os
import glob
import json
import shutil
import numpy as np
from utils import *

# %% [markdown]
# ### Setting-up labels

# %%
images_dir = r"C:\Users\wn00217454\computer_vision\Tasks\match_similarity\data\pliers_raw_clean"
images_dir = r"C:\Users\wn00217454\computer_vision\thesis\data\datasets\test_set\generated\train_gen_small\141874"
images_dir = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique\1271810"
folder_path = images_dir
os.path.isdir(images_dir)
# Out:
# True

# %%
images = glob.glob(os.path.join(images_dir, "*.webp"))
images = glob.glob(os.path.join(images_dir, "*.jpg"))
images[:5], len(images)
# Out:
# (['C:\\Users\\kaleem\\Learn\\Wuerth\\thesis\\data\\data_temp\\datasets_temp\\test_set\\classes\\unique\\1271810\\1271810_new.jpg'],
#  1)

# %%
images[0].split(".")[0].split("\\")[-1]
#int(images[0].split(".")[0].split("\\")[-1])
# Out:
# '1271810_new'

# %% [raw]
# os.path.exists(os.path.join(folder_path, os.listdir(folder_path)[0])), os.path.join(folder_path, os.listdir(folder_path)[0])

# %%
img = cv2.imread(r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique\141874\141874_new.jpg")
img.shape
# Out:
# (960, 960, 3)

# %%
os.path.join(images_dir, os.listdir(images_dir)[0])
# Out:
# 'C:\\Users\\kaleem\\Learn\\Wuerth\\thesis\\data\\data_temp\\datasets_temp\\test_set\\classes\\unique\\1271810\\1271810_new.jpg'

# %%
cv2.imread(os.path.join(images_dir, os.listdir(images_dir)[0])).shape
# Out:
# (960, 960, 3)

# %%
from PIL import Image
Image.open(os.path.join(folder_path, os.listdir(folder_path)[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x960>

# %%
image_path = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique\141874\141874_new.jpg"
os.path.exists(image_path)
# Out:
# True

# %%
img = cv2.imread(image_path)
img.shape
# Out:
# (960, 960, 3)

# %%
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x960>

# %%
new_images_dir = r"C:\Users\wnxxxxxx\computer_vision\thesis\data"
new_images_dir = r"C:\Users\wnxxxxxx\computer_vision\thesis\data\datasets\test_set\data"
new_images_dir = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new"
#images_class_dir = os.path.join(new_images_dir, "labelled_dataset")
images_class_dir = new_images_dir
#os.makedirs(images_class_dir, exist_ok = True)
os.path.isdir(images_class_dir)
# Out:
# True

# %%
for image in images:
    name = image.split(".")[0].split("\\")[-1]
    new_path = os.path.join(images_class_dir, name)
    os.makedirs(new_path, exist_ok = True)
    shutil.copy(image, new_path)

# %%
images_class_dir
# Out:
# 'C:\\Users\\kaleem\\Learn\\Wuerth\\thesis\\data\\data_temp\\datasets_temp\\test_set\\classes\\unique_new'

# %%
os.listdir(images_class_dir)
# Out:
# ['1271810_new']

# %% [markdown]
# ### Expanding dataset

# %%
images_class_dir, os.listdir(images_class_dir)
# Out:
# ('C:\\Users\\kaleem\\Learn\\Wuerth\\thesis\\data\\data_temp\\datasets_temp\\test_set\\classes\\unique_new',
#  ['1271810_new'])

# %%
save_folder = r"C:\Users\wn00217454\computer_vision\thesis\data\expand_labelled_dataset_small"
save_folder = r"C:\Users\wn00217454\computer_vision\thesis\data\datasets\test_set\data_gen"
save_folder = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\rotated_data_new"
for folder in os.listdir(images_class_dir):
    folder_path = os.path.join(images_class_dir, folder)
    print(folder_path)
    save_path = os.path.join(save_folder, folder)
    for degree in np.arange(0, 361, 36):
        print(os.path.exists(save_path))
        save_rotated_images(folder_path, degree, save_path)
# Out:
# C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new\1271810_new
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ### Arranging number of classes

# %% [markdown]
# Arrange the product names in sequences (0 to n product models) for better data management and organization.

# %%
save_folder = r"C:\Users\wnxxxxxx\computer_vision\thesis\data\expand_labelled_dataset"
save_folder = r"C:\Users\wnxxxxxx\computer_vision\thesis\data\datasets\test_set\data"
os.chdir(save_folder)
os.getcwd()
count = 0
mappings = {}
for folder_name in os.listdir(save_folder):
    mappings[count] = folder_name
    folder_path = os.path.join(save_folder, folder_name)
    new_folder_path = os.path.join(save_folder, str(count))
    os.rename(folder_name, str(count))
    count += 1

# %%
json_file_path = "mappings.json"
with open(json_file_path, 'w') as json_file:
    json.dump(mappings, json_file, indent = 4)

# %%
products_imgs_dir = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new"
save_dir = r"C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\rotated_data_new"
def augment_data_rotation(products_imgs_dir, save_dir, degrees = 36):
    if os.path.isdir(images_dir):
        
        # Augmentation
        for folder in os.listdir(products_imgs_dir):
            folder_path = os.path.join(products_imgs_dir, folder)
            print(folder_path)
            save_path = os.path.join(save_dir, folder)
            for degree in np.arange(0, 361, 36):
                print(os.path.exists(save_dir))
                save_rotated_images(folder_path, degree, save_path)
        
    else:
        print("No images found in the directory!")
        exit(0)
        
augment_data_rotation(products_imgs_dir, save_dir)
# Out:
# C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new\1271810_new
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
from augment_data import *
augment_data_rotation(products_imgs_dir, save_dir)
# Out:
# C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new\1271810_new
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# C:\Users\kaleem\Learn\Wuerth\thesis\data\data_temp\datasets_temp\test_set\classes\unique_new\1271810_new
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
