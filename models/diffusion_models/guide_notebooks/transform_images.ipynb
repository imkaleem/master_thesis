# %%
import os
import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
images_dir = r"C:\Users\wn00217454\computer_vision\thesis\data\datasets\dataA"
images_paths = glob.glob(os.path.join(images_dir, "*.jpg"))
image_path = images_paths[0]
img = cv2.imread(image_path)
plt.imshow(img)
