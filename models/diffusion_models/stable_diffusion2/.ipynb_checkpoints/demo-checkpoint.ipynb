# %%
cd /datalake/WMLA/data/d_1401/projects/d_00217454/code/dev/gen_ai_vision_lab
# Out:
# /datalake/WMLA/data/d_1401/projects/d_00217454/code/dev/gen_ai_vision_lab

# %%
mkdir experiments

# %%
import torch
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

device = torch.device("cuda:0")

model_id = "stabilityai/stable-diffusion-2"
model_id = r"/datalake/homes/u_1401_00217454_x/.cache/torch/hub/checkpoints/genai/stable-diffusion-2-base"

# Use the Euler scheduler here instead
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to(device)
# Out:
# ...
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 20.26it/s]

# %%
prompt = "wooden table surface with the fine texture, 2D"
image = pipe(prompt).images[0]

image.save("table35.png")
image
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 19.40it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
